# %% [markdown]
# # 10 - Pandas I: Accessing and Exporting Tabular Data

# %% [markdown]
# Original content from Felipe Alvarez de Toledo available at https://github.com/FelipeAdeT/PythonforHumanities
#
# Content adaptation and modifications by Maroussia Bednarkiewicz.

# %% [markdown]
# ### Navigation reminder
#
# - **Grey cells** are **code cells**. Click inside them and type to edit.
# - **Run**  code cells by pressing $ \triangleright $  in the toolbar above, or press ``` shift + enter```.
# -  **Stop** a running process by clicking &#9634; in the toolbar above.
# - You can **add new cells** by clicking to the left of a cell and pressing ```A``` (for above), or ```B``` (for below).
# - **Delete cells** by pressing ```X``` or the bin symbol in the right upper corner of the cell.
# - Run all code cells that import objects (such as the one below) to ensure that you can follow exercises and examples.
# - Feel free to edit and experiment - you will not corrupt the original files.

# %% [markdown]
# ## Introduction
#
# (Adapted from Eric Monson's Pandas workshops, see https://github.com/emonson/pandas-jupyterlab.
#
# Oftentimes, we don't have a text file, organized into lines, but a spreadsheet with tabular data arranged into rows and columns, which will often be CSV (Comma Separated Value) or Excel files. This is the case of the metadata from the Project Gutenberg. Most metadata are stored in a tabular format.
#
# There are several ways one could structure CSV data, such as in lists of lists, combinations of dictionaries and lists, or arrays, but the Pandas module provides an efficient functionality for working with tabular data (i.e., spreadsheets).
#
# **Pandas** is a module for data manipulation and analysis that provides a powerful solution for working with spreadsheet data. This module contains powerful methods for the manipulation, analysis and plotting of such data, and is worth getting to know from the beginning. The upcoming two lessons are focused on using Pandas.
#
# ---
# Please run the code cell below to import the exercises for this lesson. The code will print a sentence if the exercises have been successfully imported.

# %%
# @title Grant GoogleColab access to your GoogleDrive and import questions for this notebook
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Add your module folder to Python path
import sys
module_path = f"/content/drive/My Drive/IDH/Notebooks"
sys.path.append(module_path)
print("GoogleColab can now access your GoogleDrive.")

# import exercises for this lesson
from QuestionsPandas import E1, E2, E3, E4, E5, E6, E7, E8, Q1, question, solution

# %% [markdown]
# ---
# ## Lesson goals
#
# - **Import** .csv and Excel spreadsheets with Pandas
# - Assign row **indices**
# - Access information through **[]**, **.loc[]**,**.iloc[]** and recognize **.** notation
# - **Select data** within columns with conditionals
# - **Export** spreadsheets as files
#
# **Key Concepts:** DataFrame, Series, index

# %% [markdown]
# ---
# # Importing Files with Pandas
#
# The ```pandas.read_csv()``` method is similar to the ```file.read()``` method, but this is a method of pandas specifically designed for .csv files.
#
# ```python
# import pandas as pd
#
# file = pd.read_csv('filepath or filename.csv')
# ```
# Where we are using the read_csv() method and assigning the object created to the variable 'file'. The read_csv method requires a filepath or filename with its extension.
#
# There are many other options, including specifying rules for reading the header, specifying the encoding, etc., which are described in the pandas [documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html).
#
#
# Similarly, Pandas has another command for importing Excel spreadsheets. Excel files have the added complication that they can hold many spreadsheets at once, so you may have to specify the sheet in question:
#
# ```python
# file = pd.read_excel('file.xlsx', sheet_name='sheetname')
# ```
#
# Let's import the CSV spreadsheet with the metadata of Project Gutenberg to use as an example for this lesson.
#
# We first import `pandas` module and give it a short name `pd`:

# %%
import pandas as pd

# %% [markdown]
# Note that if you do not use the short name, you will have to use the full name, `pandas`, each time you use functions from this module. The short name makes your code more readable.

# %%
# Use the method `read_csv` to import PG metadata from the csv file
PGmetadata = pd.read_csv(f"{module_path}/PG/pg_catalog.csv")

# %% [markdown]
# Pandas will create a **Dataframe** for your CSV spreadsheet, an object that allows you to display your data in rows and columns. DataFrames can be operated on. You can extract information, as well as append new data and perform queries.
#
# # An initial view of the DataFrame
#
# We can gauge the contents of the dataframe in a few ways, upon opening it. Pandas offers a few methods that can help.
#
# ```df.head()``` and ```df.tail()``` allow us to see the first and last rows of the dataframe, respectively.

# %%
PGmetadata.head()

# %% [markdown]
# It has printed the **5** first rows of the dataframe. If we want to specify the number of rows to view, we can include that number in the parentheses:

# %%
PGmetadata.tail(3)

# %% [markdown]
# As we can see, this helps us get a first view of the dataframe. We can generate a list of columns with  ```df.columns```.  This is especially useful for dataframe with large numbers of columns.
#
# **Note:** You might notice that this command does not have a parenthesis; that is because it is an attribute of the dataframe, not a method (function).

# %%
PGmetadata.columns

# %% [markdown]
# We can also print only the list of columns' titles:

# %%
PGmetadata.columns.tolist()

# %% [markdown]
# # The Pandas Dataframe
#
# > **Pandas Series:** One-dimensional container for data. Each series has an index and potentially a name, as well as a data type.
#
# > **Pandas DataFrame:** Two-dimensional tabular structure with labels (rows and columns), where each column is a series.
#
# Columns in a Pandas DataFrame are each a Series, with a name (the column header) and an index. The index numbers are the labels for the entries within a series. These keep the columns aligned correctly into rows, preserving the integrity of the data.
#
# One of the advantages of the DataFrame is that it allows us to store different types of values in different columns, including numbers, strings, and null values. Each column has a data type, which you can check using ``` df.dtypes```:

# %%
PGmetadata.dtypes

# %% [markdown]
# The naming of object types on Pandas is slightly different from the built-in Python datatypes, but refers to similar structures.
#
# | Pandas Datatype| Python Datatype |
# |--|--|
# |object|str or mixed|
# |int64|int|
# |float64|float|
# |bool|bool|
#
# >Source: https://pbpython.com/pandas_dtypes.html

# %% [markdown]
# # Specifying the index
#
# If you do not specify an index for rows, Pandas will create an index of integers, as it did above (the untitled column to the left).

# %%
PGmetadata.index

# %% [markdown]
# We can **specify an index** from one of the columns of our dataframe. It does not have to be numbers: they can be any identifier including integers, strings or dates. We can even use a column with non-unique values, but this might cause difficulties later on.
#
# There are two ways to specify an index: we can do so when we create the DataFrame, or after it has been created.
#
# To specify an index **when creating** the dataframe, add the following argument when using read_csv (or equivalent):
#
# ```python
# df = pd.read_csv('filename.csv', index_col='col_name')
# ```
#
# To specify an index **after creating** the DataFrame, use:
#
# ```python
# df = df.set_index('col_name')
# ```
#
# By now, you should understand that we are reassigning the variable 'df' to this updated dataframe.
#
# Alternatively, using
#
# ```python
# df.set_index('Year', inplace=True)
# ```
#
# would allow us to forgo that reassignment.
#
# Let's specify our DataFrame's index.

# %% [markdown]
# ### Exercise 1
#
# Have a look at PGmetadata. Which column could be used as index? Choose the right column, and use the next cell to set the index on the dataframe that we have created, PGmetadata, **using the df.set_index() method with the 'inplace' parameter**.

# %%
# Set index to PGmetadata

# %% [markdown]
# Use the next cell to import the CSV with PG metadata and set the index with the importation of the file.

# %%
# Import PG metadata CSV file with index
PGmetadata =

# %%
solution(E1)

# %% [markdown]
# ---
# # Accessing information in DataFrames
#
# We can call data in a cell, column or row by using labels and indices. There are different, overlapping ways to do this, and these can cause some confusion. We will introduce the preferred methods for accessing data, as well as a few other methods because you will encounter them in documentation and existing examples (and there are more!). But we recommend sticking to the methods developed in detail.
#
# ---
#
# ## 1. One-dimensional indexing: **square brackets []**
#
# Using square brackets alone, you can perform selections of different types based on one dimension (columns or rows, depending on whether you use column names or index values).  It can get complex because it will yield varying output depending on what you put into the square brackets.
#
# ### Square brackets with column names
#
# To fetch a **single column**, simply specify the **column name** inside square brackets.
#
# ```python
# df['column_name']
# ```
#
# For instance, let's fetch the 'Title' column from our dataframe using this notation:

# %%
PGmetadata['Title']

# %% [markdown]
# One thing we might notice is that this is not formatted in the same way as our dataframe. Because our output is **one-dimensional**, pandas is outputting a **Series**. If it were a single value it would output a single data point (such as a string or a number type). When we make a two-dimensional selection, it will output a DataFrame.
#
# We might also notice that the output only displays a few rows. When fetched in this way, Jupyter only exhibits the first and last few rows from the selection, but it has indeed fetched all of them. You see that the length gives you the full number of rows.

# %% [markdown]
# To access **multiple columns**, we can include a **list** of column names in our request. Recall that lists are bounded by square brackets, and its items separated by commas.
#
# This results in a –slightly odd– double-bracket notation:
#
# ```python
# df[['column_1','column_2']]
# ```
#
# Let's fetch the Title and Authors of all rows from our DataFrame:

# %%
PGmetadata[['Title','Authors']]

# %% [markdown]
# As we can see, the output is indeed a DataFrame.
#
# ### Exercise 2:
#
# In the two cells below, write a code that will select (1) the column with subjects, and (2) the columns with titles, authors, and subjects, following the examples we have just covered. Make sure you write the names of the columns right.

# %%
solution(E2)

# %% [markdown]
# ### Question 1
#
# **Run the cell to see the question.**

# %%
question(Q1)

# %% [markdown]
# ### Creating copies from bracket selections
#
# Because of the complex structures underlying dataframes, assigning square bracket selections to a variable  to create a new dataframe does not guarantee that you are acting on a copy or on the original. When you perform operations on your supposed copy, it will give you a warning message.

# %%
title_author = PGmetadata[['Title','Authors']] # assign a selection to a variable

# %%
title_author['Title'] = '' # replace the values in the title column with blanks

# %% [markdown]
# To ensure that a copy is made, or to avoid the warning message, we should edit a copy of the dataframe using .copy() at the end of our command:
#
# ```python
# df[['column_1','column_2']].copy()
# ```

# %%
title_author = PGmetadata[['Title','Authors']].copy()

# %%
title_author['Title'] = ''

# %% [markdown]
# ### Exercise 3
#
# In the empty code cell below, create a new dataframe 'PGbookshelves' that contains a copy of our PGmetadata dataframe, selecting only the columns with title and bookshelves. Then run the subsequent code cell, which should not give you an error.

# %%
# Sets all values in the column to None (NA or blank)
PGbookshelves['Bookshelves'] = None

# %%
solution(E3)

# %% [markdown]
# ### Conditional selections: square brackets with a boolean for rows selection
#
# We can generate more complex selections combining square brackets and conditional statements.

# %% [markdown]
# ### Exercise 4:
#
# In the cell below create a new dataframe called `PGauthors` using the CSV file `pg_authors.csv` that you can find in the same folder as the `pg_catalog.csv`, which we used for our PGmetadata. You do not need to set an index.

# %%
solution(E4)

# %% [markdown]
# Let's inspect the dataframe that you have created.

# %%
PGauthors.head()

# %% [markdown]
# As you can see, the columns with the `birth` and `death` dates, contain float numbers. But dates should be integers, they cannot have decimal points. In the next cell, we will thus convert all the dates into integers. We select each column and use the method `.astype()` to convert the data in the given column to integers of the type `Int64`.

# %%
PGauthors["birth"] = PGauthors["birth"].astype("Int64")
PGauthors["death"] = PGauthors["death"].astype("Int64")

# %% [markdown]
# Let's inspect our dataframe again.

# %%
PGauthors.head()

# %% [markdown]
# As you can see, the dates have been converted into integers; they do not have decimal points anymore.
#
# Now, we can select all the authors who died after 1900, using a boolean condition.

# %%
PGauthors['death'] > 1900

# %% [markdown]
# As can be seen above, using a boolean condition on a series returns a series of True/False values.

# %% [markdown]
# We can use these values to select the matching contents. We insert the condition into square brackets to make selections within a column. The syntax is a bit messy, requiring us to fully specify the condition, which requires calling the dataframe and column name together inside the brackets:
#
# ```python
# df[df['column_name']>0]
# ```
#
# This specification will return all columns for the rows for which the condition is true.
#
# So, for instance, say we wanted to select all the rows for authors who died before 1400:

# %%
PGauthors[PGauthors['death']<=1400]

# %% [markdown]
# The above has returned 95 rows (Python counts the 0 [zero] as a row, hence it counts 94 rows).
#
# We can add further complexity by including multiple conditions using the logical operators "or" (|) and "and" (&).
#
# Say we are only interested in authors from the 11th and 12th centuries. We can select the authors from this period using the following conditions:

# %%
PGauthors[(PGauthors['birth']>=1000) & (PGauthors['death']<1200)]

# %% [markdown]
# ### Exercise 5
#
# In the cell below, make a selection of all rows in PGauthors where the language is Spanish, that is "es".
#
# If you are having trouble, it might be helpful to first design the conditional statement, and then place it into a square-bracket selection structure. Remember that the conditional operator for equality is **not** a single equals sign, and do not forget to surround strings with quotes.

# %%
solution(E5)

# %% [markdown]
# ### Exercise 6
#
# Now that you have successfully made a conditional selection, use the cell below to create another selection with two conditions. From PGauthors, select only rows where the authors died before 1400 and wrote in Spanish. Remember to surround individual conditions in parentheses.

# %%
solution(E6)

# %% [markdown]
# ---

# %% [markdown]
# # Single-axis selection alternative: dot notation
#
# An alternative to bracket notation is to use dots to refer to columns:
#
# ```python
# df.column_name
# ```
#
# The syntax is used frequently because it saves some typing, but it has several issues. It does not work when:
#
#     - There are spaces in the column name
#     - The column name is the same as a Dataframe method (ex. count)
#     - The column name is a variable.
#
# For these reasons, it is best to stick to the bracket notation.
#
# ---
# ## 2. Two-axis selection:  ```.loc[]``` using labels
#
# The options above were used to select data across one axis, for instance making a selection of some columns for all rows, or of all columns for some rows.
#
# ```.loc[]``` allows us to locate items that match given conditions in both rows and columns, using their labels (the row indices and the column names).
#
# The basic structure is:
#
# ```python
# df.loc[rows,columns]
# ```
# where you supply information on the rows and columns you want to fetch. Like with square brackets, we can insert single values, lists, ranges and conditions into the brackets to create different types of selections.
#
# ### Selecting a single cell with ```.loc[]```
#
# Simply, you give the coordinates of the cell in terms of its row and column:
#
# ```python
# df.loc[row_index,'columname']
# ```

# %% [markdown]
# ### Exercise 7
#
# In the cell below, using ```.loc[]``` notation, find the cell that gives the 'raw_entry' of the item with index 32979.

# %%
solution(E7)

# %% [markdown]
# ### Selecting a group of cells through .loc[] with lists
#
# You can supply lists for the rows and/or columns if you want to make a selection from several of them. This once again leads to the unsightly double bracket, but works well:
#
# ```python
# df.loc[[row1,row2,row3],['column1','column5']]
# ```

# %%
PGauthors.loc[[32978, 32979, 32980], ['last_name', 'first_name', 'birth', 'death']]

# %% [markdown]
# ### Selecting ranges of cells through .loc[] with slicing
#
# And, as we saw with lists and strings, we can also slice into a dataframe by giving ranges with a colon.
#
# ```python
# df.loc[row1:row3, column1:column5]
# ```
# As with other instances of slicing, you can leave the slice partly blank to grab from beginning/to end. A colon by itself selects the whole range from beginning to end, and can be used to perform a single-axis selection while consistently using the .loc[] notation throughout your code.

# %%
PGauthors.loc[:,'last_name']

# %%
PGauthors.loc[:,'last_name':'death']

# %% [markdown]
# Slicing into ranges works both for numerical indices as well as other labels, such as the column names. The selection will follow the order in which these labels appear in the dataframe, not an order based on their content. That is, the columns are not selected alphabetically unless they have been thus sorted. This can lead to non-intuitive results when the index is not sorted by value.

# %% [markdown]
# ### Conditional selections with .loc[] and Boolean conditions
#
# Boolean series can be used in the manner described before to select from columns and rows. This is perhaps easier to read than with single-axis selections, because we are explicit about both rows and columns:
#
# ```python
# df.loc[df['colname'] <  1, :]
# ```
#
# In the example above, we selecting the rows that fulfill a condition, and all columns.

# %%
PGauthors.loc[PGauthors['death'] < 1200,:]

# %% [markdown]
# Using conditionals with strings is a more efficient way to work on DataFrames, rather than looping through columns.
#
# ### Exercise 7
#
# Use ```.loc[]``` notation on the PGauthors DataFrame to select
# - last names,
# - first names,
# - death dates, and
# - languages
#
# of the authors who died before  1100.

# %%
solution(E8)

# %% [markdown]
# ## Two-axis selection alternative: ```df.iloc[]``` using integers
#
# ```.iloc[]``` works in a similar way to ```.loc[]```, but instead of supplying labels, we can supply positions. In that sense, it is less human-readable and may lead to more error. You will, however, encounter it in online solutions and other peoples' code, so it is worth knowing.
#
# For instance, if we know that the 'raw_entry' column is in position 6 (the seventh column aside from the index), we can call the 32979th cell in this column.

# %%
# Select row 32979 of the 7th column
PGauthors.iloc[32979, 6]

# %% [markdown]
# Notice that this is the same as the cell we called in  the first ```.loc[]``` example, which we called in this way: ```PGauthors.loc[32979, 'raw_entry']```. With `loc` we used the index and the column name, whereas with `iloc`, we use the row and column positions or indices to the same effect.
#
# ---

# %% [markdown]
# # Exporting files with Pandas
#
# Pandas allows us to export our dataframes into different types of files. Briefly, the commands for exporting to .csv, excel and .json files are as follows:
#
# ### Saving to CSV
#
# ```python
# df.to_csv('filename.csv',encoding='',index=False)
# ```
# **Tip** index=False allows us to drop the index, which is useful if index was autocreated. Otherwise, as we export and import the data in successive sessions, we start accumulating old indices from previous sessions as new columns.
#
# ### Saving to Excel
#
# ```python
# df.to_excel('filename.xlsx',sheet_name='sheet')
# ```
#
# ### Saving to JSON
#
# ```python
# df.to_json('filename.json', orient='records')
# ```

# %% [markdown]
# ---
# # Lesson Summary
#
# - Pandas organizes tabular data into DataFrames
# - Import .csv and Excel spreadsheets with Pandas .read_csv() and .read_excel()
# - You can assign row indices with .read_csv(file, index_col = 'column_name') or with df.set_index('column_name')
# - There are multiple methods for accessing information in a dataframe:
#     - single-axis (rows or columns): square brackets []
#     - multi-axis (rows and columns: .loc[] using labels, .iloc[] using indices
#     -  . notation - you should be familiar with it, but it is not recommended
# - Conditionals can be used within these selections
# - Export DataFrames as files using df.to_csv(). df.to_excel() or df.to_json().
