# %% [markdown]
# # 01 - Reading Python Script: Syntax

# %% [markdown]
# Original content from Felipe Alvarez de Toledo available at https://github.com/FelipeAdeT/PythonforHumanities
#
# Content adaptation and modifications by Maroussia Bednarkiewicz.

# %% [markdown]
# ### Navigation Reminder
#
# - **Grey cells** are **code cells**. Click inside them and type to edit.
# - **Run**  code cells by pressing $ \triangleright $  in the toolbar above, or press ``` shift + enter```.
# -  **Stop** a running process by clicking &#9634; in the toolbar above.
# - You can **add new cells** by clicking to the left of a cell and pressing ```A``` (for above), or ```B``` (for below).
# - **Delete cells** by pressing ```X``` or the bin symbol in the right upper corner of the cell.
# - Run all code cells that import objects (such as the one below) to ensure that you can follow exercises and examples.
# - Feel free to edit and experiment - you will not corrupt the original files.

# %%
# @title Grant GoogleColab access to your GoogleDrive and import questions for this notebook
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Add your module folder to Python path
import sys
module_path = f"/content/drive/My Drive/IDH/Notebooks"
sys.path.append(module_path)
print("GoogleColab can now access your GoogleDrive.")

# Import exercises
from QuestionsSyntax import Q1, Q2, Q3, E1, E2, E3, question, solution

# %% [markdown]
# ## Introduction
#
# Much of humanists' work will be to read and understand others' code, so you can reuse  what has already been done by other or collaborate with programmers.
#
# In Lesson 1, we will look at some basic issues of **syntax** (form). In Lesson 2, we will look at some basic Python **semantics** (meaning). The goal is to become comfortable with reading Python code.
#
# ---

# %% [markdown]
# ## Lesson Goals:
#
# - Recognize overarching Python syntax (comments, statements, codeblocks, variable assignment)
# - Assign variables with `=`
# - Know naming rules
# - Understand basic error messages
#
# **Key Concepts:** algorithm, pseudocode, statement, code block, variable, error message
#
# ---
# # A recipe for a task
#
# Though code might seem imposing, it is only a language: one that allows humans to speak to computers.
#
# In other words, code is a set of instructions we give to a computer. It is a recipe we hand to the computer to solve a particular problem.
#
# In this course, we will come to understand the ingredients and instructions that go into that recipe.
#
# >**Algorithm:** a general procedure for solving a problem in a finite number of steps.
#
# >**Program:** A set of instructions that can be executed by a computer.
#
# When faced with a programming language, translating lines of code into plain English is a useful strategy.
#
# >**Pseudocode:** A detailed description of what a program or algorithm must do, expressed in a natural language rather than a programming language.
#
# Let us start with a concrete example.
#
# We want to know whether a given topic is featured in a corpus of document, called the [Project Gutenberg](https://www.gutenberg.org/), which contains over 75'000 items. The copyrights of these documents have expired and they are freely accessible.
#
# For each document stored in the Project Gutenberg corpus, there is a file with metadata. This file contains the type of document (whether it is a text, an image, etc.), the name of the book, the language(s), the author(s)'s first and last names, the dates of birth and death of the author (if they are known), the genres to which the document belong, and the topics, to which the document relates. You find one of these metadata file in your course folder, in the folder called PG (for Project Gutenberg). The file is called `pg1.rdf`. It contains the metadata for the first document in the Project Gutenberg corpus. Download the file and open it.
#
# As you can see it is difficult to read. We will explore the format used to write this file. But for now, we will use some help to display the information contains in the metadata file.
#
# If you go to the Project Gutenberg website, to the page corresponding to the the metadata file that you have just opened, you can see all the information stored as metadata in the secion [_About this eBook_](https://www.gutenberg.org/ebooks/1). Your browser has parsed the code in the file that you have opened and followed the instructions to display the information as you see them, in a table.
#
# We can achieve a similar result with few pythonic lines of code.
#
# We have stored all the metadata files for each document in the Project Gutenberg in a file in a [csv format](https://en.wikipedia.org/wiki/Comma-separated_values) (Comma-Separated Values). The cells below will store the content of the file with its 76'236 entries in a variable called `pg_metadata`.

# %%
# @title Run the following cell to get the metadata from the Project Gutenberg.
import os
csv_path = os.path.join(module_path, "PG/pg_catalog.csv")

# Import useful library to read CSV files
import csv

# Open the CSV file and store the data in a list called `pg_metadata`
with open(csv_path, newline='', encoding='utf-8') as csvfile:
    pg_reader = csv.DictReader(csvfile)
    pg_metadata = list(pg_reader)  # Convert iterator to list

print("The metadata of the Project Gutenberg are stored as a list in pg_metadata.")

# %% [markdown]
# ### What is the first document stored in the Project Gutenberg?
# _Run the next cell to find out_

# %%
# Python count always starts with 0 (zero)
# When you want the first item of anything in Python, you must use a 0 (zero)
print(pg_metadata[0]['Title'])  # Display the title of the first book

# %% [markdown]
# ### Which metadata are stored for this document?
# _Run the next cell to print the metadata for the first document stored in the Project Gutenberg database._

# %%
# Display the raw metadata for this document.
pg_metadata[0]

# %% [markdown]
# ### JSON format
# The metadata are stored in a JSON format. JSON (JavaScript Object Notation, https://www.json.org/json-en.html) format is often used to store metadata that will be read by a computer. It is not meant to be read by humans. We will read it with a Python module that process structured data and display them in dataframes. The module is called Pandas.

# %%
# Import the necessary module
import pandas as pd
# Set display option to not truncate column content
pd.set_option('display.max_colwidth', None)
# Create a Python Pandas Dataframe, i.e. a table.
pg = pd.DataFrame(pg_metadata).set_index('Text#')
pg[:1]

# %% [markdown]
# ## How can we use these metadata with Python?
#
# Let's imagine a task, transcribe it into a pseudocode, translate the pseudocode to code and execute the programme.
#
# We want to know whether the Project Gutenberg cotains documents on a specific topic that is **not** listed in the categories 'Subjects' or 'Bookshelves'. We want our programme to parse the 76'236 titles in the Project Gutenberg's metadata that we stored in `pg_metadata` and outputs all the documents' titles which contain the chosen topic.
#
# ### Pseudocode
#
# 1. First, we define our topic.
# 2. Then we go (or **loop** in Python language) through all the entries we have in our metadata, stored in `pg_metadata`.
# 3. If our topic is found in the title of a document, our programme must print the title and the author of the document.
#
# In the cell below we have translated this pseudocode into actual Python code. Read the code and execute the cell.
#
# ### Code

# %%
topic = "Segovia"
for book in pg_metadata:
  if topic in book['Title']:
    print(book['Title'], "by", book['Authors'], "\n----------------------")

# %% [markdown]
# ### Try with another niche topic of your choice.
#
# _Replace "MY_TOPIC" with a word that you would like to search in the titles of PG's documents._

# %%
my_topic = "MY_TOPIC"
for book in pg_metadata:
  if my_topic in book['Title']:
    print(book['Title'], "by", book['Authors'], "\n----------------------")

# %% [markdown]
# This simple piece of code hopefully illustrates that it helps to try to translate code into a human language to figure out its meaning, or plan our approach to a problem.
#
# We will use a rudimentary version of **pseudocode** as the course advances to give prompts and aid in code interpretation. Through pseudocode, we can put the steps that we want to happen in an algorithm into words. We can also translate code into written English, a good exercise for decyphering code that is already written.
#
# ---
# # Syntax and Semantics
#
# >**Syntax** refers to the structures of a language, whereas **semantics** refers to meaning.
#
# They would be our recipe's instructions and ingredients.
#
# In the first two lessons, we will look at the general syntax and semantics of Python. Throughout the course, we will explore essential syntactical and semantical components more deeply.
#
# # Syntax: Reading Code
#
# Python is a high-level programming language that prioritizes human readability. Python's syntactic structure makes it easy for humans to read.
#
# ## A. Comments
#
# Comments can be added following a **hashtag (#)**, so you can add explanatory notes for yourself and others as you write your code. Anything written after a # in the same line will not run.
#
# Comments can be added **on separate lines** or **inline, after any active code**. They do not affect indentation.
#
# So, for instance, if we have some code:
#
# ```python
# x = 3 # We can comment in line, after active code
# # or comment on a separate line
# ```
#
# You will also find that people use hashtags to "comment out" code that they don't want to run, but might want to keep for other reasons. If you put a hashtag in front of code, it will be turned into a comment and will be executed.
#
# ```python
# #x = 3
# # the code above has been commented out.
# ```

# %%
# @title Here is our code from above with comments

# We want to know if a topic is featured in the Project Gutenberg
# We define our topic using a variable.
topic = "Segovia"
# We loop over each entry of the metadata file extracted from PG
for book in pg_metadata: # pg_metadata holds PG's metadata
  # We define as condition that the topic must be in the document's title
    if topic in book['Title']:
      # We print only the title containing the given topic.
        print(book['Title'], "by", book['Authors'], "\n----------------------")

# %%
# Don't forget to read these comments when they appear in a cell!

# %% [markdown]
# Below is the first exercise in our lessons. Run the code cell (the code cell immediately below this one), and the question will appear. Then type your answer (a,b,c or d) in the white space and press enter to get feedback.
#
# ### Question 1

# %%
question(Q1)

# %% [markdown]
# ---

# %% [markdown]
# ## B. Reading Whitespace
#
# > **Whitespace:** Characters that do not represent visible marks, but fill space.
#
# While other languages ignore whitespace, Python uses line breaks and indentations to structure code. This makes code easy to follow because it minimizes the number of brackets, braces and other punctuation in the code.
#
# Compare our code written in Python with the same example written in Java, another popular language (that ignores whitespace).
#
# **Python:**
# ```python
# topic = "Madrid"
# for book in pg_metadata:
#   if topic in book['Title']:
#     print(book['Title'], "by", book['Authors'], "\n----------------------")
# ```
#
# **Java:**
# ```java
# String topic = "Madrid";
#
# for (Map<String, String> book : pg_metadata) {
#     String title = book.get("Title");
#     if (title != null && title.contains(topic)) {
#         String authors = book.get("Authors");
#         System.out.println(title + " by " + authors);
#         System.out.println("----------------------");
#     }
# }
# ```
#
# As we can see, Python is more intuitive, and minimizes the chances that we will forget to close brackets, parentheses, or make other syntactical mistakes.
#
# Each programming language has its advantages and its inconvenients. Another popular programming language in social sciences and the Humanities is R. Our lines of code in R would look like this:
#
# **R:**
# ```R
# topic <- "Madrid"
#
# for (i in 1:nrow(pg_metadata)) {
#   title <- pg_metadata$Title[i]
#   if (grepl(topic, title)) {
#     authors <- pg_metadata$Authors[i]
#     cat(title, "by", authors, "\n----------------------\n")
#   }
# }
# ```
#
# This is much less readable than Python. But a more idiomatic way to obtain our results in R could fit in just one line.
#
# **R:**
# ```R
# topic <- "Madrid"
# subset(pg_metadata, grepl(topic, Title), select = c("Title", "Authors"))
# ```
#
# This code is not only concise, it is also fast because it uses vectors with `grepl`. We will talk about vectors in a forthcoming session. For now, you should simply know that different needs can lead scholars to choose different programming languages, and none of these languages is superior or inferior to the others on all grounds. You might therefore encounter different programming languages and you should never hesitate to use AI assistants to help you if you need to deal with a language that you do not know.
#
# Let's get back to Python and look at Python's rules for using whitespace.
#
# ### 1. Line Breaks make Statements
#
# In Python, each **line** represents a **statement**. Each line break starts a new statement.
#
# >**Statement:** A syntactic unit that expresses one action to be carried out.
#
# You can override this rule and continue an expression on a new line by ending with **\** or if using parentheses. You can also optionally include multiple statements in one line by using **;** to separate statements.

# %% [markdown]
# ### 2. Indents create Codeblocks
#
# **Indentation** creates **code blocks**.
#
# >**Code block:** A set of statements that are executed together.
#
# A code block starts with a statement ending in a colon **:**
#
# Statements within the code block are indented. Anything at the same level of indentation belongs to the same block of code.
#
# Reducing the indentation back to the previous level ends a code block.
#
# Blocks can be **nested**. That is, code blocks can be inserted into other code blocks. This is done by indenting further.
#
# Python is strict about indentation. Always use **four spaces** to indent code. If you want to indent further (create a nested block), add four more spaces. Do not use tabs. Oftentimes, unexpected errors are due to issues with indentation.
#
# For example, in the code we saw previously:

# %%
#Below is a statement
topic = "Segovia"

#  Below is a set of three statements.
# Everything that is indented is in the same block.
# They will finish running on every element in our metadata before proceeding with other code.

for book in pg_metadata:
  if topic in book['Title']:
    print(book['Title'], "by", book['Authors'], "\n----------------------")

# Because the next line is not indented, we have exited the previous block of code.
# The line runs once the block above is finished.
print("Do you want to search for another topic?")

# %% [markdown]
# ---

# %% [markdown]
# ### 3. Extra whitespace is not a problem
#
# Aside from indentation, Python is flexible with the inclusion of additional **whitespace**. It is not picky with spaces within lines and allows you to add blank lines.
#
# Lines without active code (blank lines or lines with comments) will not affect the way code blocks function. Use these for clarity.

# %%
topic = "Segovia"

#Python does not mind blank lines or extra spaces, use them for clarity

for book in pg_metadata:
  if topic in book['Title']:

# They won't affect indentation (so the lines above and below
# this comment will still be read as part of the same block)

    # This print statement is inside the loop.
    # It will be run each time the condition is met and as long as the loop runs.
    print(book['Title'], "by", book['Authors'], "\n----------------------")

# The print statement below is outside the loop.
# It is not indented like the previous one which belongs to the loop.
# It will run once the above loop is over.
print("Do you want to search for another topic?")

# %% [markdown]
# ### Question 2

# %%
question(Q2)

# %% [markdown]
# ---

# %% [markdown]
# **Exercise 1:** Below is some code in which significant whitespace has been removed. Taking into account that statements (units that represent a single action) occupy a line, and code blocks (sets of statements that must be run together) are indented, edit the cell to generate functional code. Test the code out until it has the expected effect.
#
# ```python
# count = 10 while count > 0: print(str(count) +"!") count = count - 1 print("lift off!")
# ```
#
# The code should
# 1. Create a variable called count with the value 10
# 2. Open a code block with a while statement.
# 3. Within the block, you should have two statements. The first one will print, and the second one will change the value of the count (i.e. the script is counting down).
# 5. Once this block has ended, you should have another statement that will print "lift off!"
#
# **Note:** if you find yourself stuck in an infinite loop, interrupt the running of the cell.

# %% [markdown]
# Edit the following cell to make it run following the instructions above.

# %%
count = 10 while count > 0: print(str(count) +"!") count = count - 1 print("lift off!")

# %%
solution(E1)

# %% [markdown]
# # Your First Statement: Variable Assignment
#
# We previously saw how a line of code in Python refers to a statement, or a unit of code that carries out one action. We will learn how to construct many statements over this course. The first and most important is assigning an object to a variable.
#
# >A **variable** is a label or name that points to an instance of an object to help call (retrieve) it.
#
# After assigning an object to a variable, you are able to use that variable to retrieve, and act upon, the object.
#
# You **assign** a variable to an object with a single **= sign**, placing the variable name on the left and its value on the right.
#
# ```python
# variable_name = object
# ```
#
# This command will not give you an output; instead, it will store the variable you created. The variable will be stored for the rest of the session, and you will be able to call it at any point by using its name.
#
# In our exemple, we assiged the value 'Segovia' to our variable `topic`.
#
# ### What will be printed if we run a cell with the following statement: `print(topic)`

# %%
# @title Run the following cell, write your answer and press enter.
answer = input("print(topic) will print the word: ")

if answer == topic:
    print("✅ Correct! In the variable 'topic' we stored the word:", topic)
else:
    print("❌ Not quite. Run the next cell to find out.")

# %%
print(topic)

# %% [markdown]
# Any instance of an object can be assigned to a variable. In this example, we were assigning a string (text) object to a variable. As we shall see later, string objects must always be surrounded by quotes.
#
# Variables are called 'variable' because they **can be overwritten.** Be careful: if you assign the name again, you will change the variable's value.

# %%
#Let's define another topic:
topic = "Paris"

# %% [markdown]
# ### What do you think will be the output of the statement:
#
# `print(topic)`?

# %%
# @title Run the following cell, write your answer and press enter.
answer = input("print(topic) will print the word: ")

if answer == topic:
    print("✅ Correct! In the variable 'topic' we stored the word:", topic)
else:
    print("❌ Not quite. Run the next cell to find out.")

# %%
#Check:
topic

# %% [markdown]
# As you can see, we have overwritten the previous value for this variable. The variable with the value "Segovia" no longer exists!
#
# To hold several pieces of text, we would have to use another object class. Many object classes for holding multiple values exist in Python; we will study them as we advance in the course. The most basic one is a list.
#
# >**List:** An ordered, changeable collection of values.
#
# Lists are denoted by **square brackets [ ]**, and its elements are separated by commas. Any object type could be a value within a list, including other lists or collections of objects (putting a list within a list is called nesting).
#
# In our example, we could save both cities' names by assigning a list to the variable `topic`. Note that in Python, we put quotes around a text value.

# %%
topics = ['Segovia', 'Paris']

# %%
topics

# %% [markdown]
# **Exercise 2:** We have three authors, Jane Austen, Charlotte Brontë, and Virginia Woolf. Use the cell below to create **one** variable that stores all names as values. Choose a clear name for this variable. Make sure to run your line of code.

# %% [markdown]
# Now check that your code created that variable by typing the variable name (and running the code cell).

# %%
solution(E2)

# %% [markdown]
# ## Choosing Variable Names
#
# In Python, we give names to the instances of objects we create. Python does not interpret names, so these can be used to our advantage. Use names that are easy to understand and remember to enhance the legibility of our code.
#
# You can choose any names you would like (with a few exceptions).

# %%
# Let's assign 'Virginia Woolf' to a variable

a = 'Virginia Woolf'
author = 'Virginia Woolf'

# %% [markdown]
# Both lines of code do exactly the same thing, but which is clearer?
# The second one is easier to understand because it holds meaning that the reader can interpret. When the readers see your variable in your code, i.e. `author`, they can easily understand that the variable holds the name of an author.
#
# ### Naming Limits:
#  - You cannot start a variable name with a number
#  - You cannot use whitespace or punctuation other than \_
#  - Some reserved words cannot be used (if, where, print...).
#      -  In Jupyter code cells, these words are rendered in green.
#  - Variable names are case-sensitive. (ex. author, Author and AuThor would be different objects, it is confusing and should be avoided).
#  - Reassigning a name will overwrite the variable.

# %% [markdown]
# ### Question 3

# %%
question(Q3)

# %% [markdown]
# ---

# %% [markdown]
# # Error Messages
#
# If something goes wrong with your code, Python will stop executing and run an error message. Error messages are additional tool in your programming toolkit.
#
# There are two types of error messages:
#
# >**Syntax Errors:** Errors that indicate that there is a mistake in the structure of your code
# >**Exceptions:** The code is structurally correct, but fails to execute for another reason (perhaps because of invalid input).
#
# Python will point to the line where the earliest error has occurred. The error name and message will give clues as to what went wrong. This will be helpful for troubleshooting when you start writing your own code.
#
# If you run the code below, you will encounter an error:

# %%
authors = ['Jane Austen', 'Charlotte Brontë', 'Virginia Woolf']

print(x)

# %% [markdown]
# In the last line of the error message, Python gives you information about the type of error and its cause. Here, it is a "NameError", and there is an issue with "x".  We never created any variable named x, so Python is complaining.
#
# The body of the error message gives you information on the context in which the error occurred. A green arrow points to the line where Python first detected the error. This is helpful for finding the approximate location of our error in longer pieces of code. It might mean that you made a mistake there, or that a mistake made earlier caused problems in that line.
#
# **Exercise 3** How would you fix the code above? Work in the code cell below to make it work, and then run it to check.

# %%
authors = ['Jane Austen', 'Charlotte Brontë', 'Virginia Woolf']

print(x)

# %%
solution(E3)

# %% [markdown]
# If we want to print each author's name on a separate line, we can use a loop similar to the one we wrote to print the documents' titles from PG which contained the word "Segovia". It would look like this:

# %%
for author in authors:
  print(author)

# %% [markdown]
# ---
# # Lesson Summary
#
# - The Python language is human-readable because of its clear syntax and semantics.
# - In it, you create instances of objects and then perform actions on them.
# - It can be read much like sentences with nouns (objects) and a syntactical structure, or like a recipe with ingredients (semantics) and instructions (syntax).
# - Comments (#) can help explain what each line is doing.
# - Each line (enter) represents a statement: an action.
# - Each code block (indent) is a set of actions performed together.
# - Error messages give insight into how to correct your code, including what caused the error and where it occurred.
